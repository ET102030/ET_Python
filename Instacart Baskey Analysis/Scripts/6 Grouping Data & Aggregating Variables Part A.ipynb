# %% [markdown]
# ## 4.8 Grouping Data & Aggregating Variables Part A

# %%
##Importing important packages

import pandas as pd
import numpy as np
import os

# %%
##Importing path, and csv files of products

path= r'/Users/erictam/Downloads/CareerFoundry Program/Data Immersion Achievement 4/Instacart Basket Analysis'

# To import 4.7 orders_prod_merged.pkl as ords_prods_merge

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.7 ords_prods_merged.pkl'))
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
#
#    order_time_hour_of_day  days_since_prior_order  product_id  \
# 0                       8               11.114836         196
# 1                       8               11.114836       14084
# 2                       8               11.114836       12427
# 3                       8               11.114836       26088
# 4                       8               11.114836       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# 1                  2          0  Organic Unsweetened Vanilla Almond Milk
# ...

# %%
# Making a subset of the first 1 million rows and using shape function to confirm
df= ords_prods_merge[:1000000]
df.shape
# Out:
# (1000000, 16)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
# 5   2398795        1             2                   3
# 6   2398795        1             2                   3
# 7   2398795        1             2                   3
# 8   2398795        1             2                   3
# 9   2398795        1             2                   3
#
#    order_time_hour_of_day  days_since_prior_order  product_id  \
# 0                       8               11.114836         196
# 1                       8               11.114836       14084
# 2                       8               11.114836       12427
# 3                       8               11.114836       26088
# ...

# %%
#Using group by on the product_name column
df.groupby('product_name')

# %%
#Running group by with an aggregate function on department_id
# Or can also use: 
# df.groupby('department_id').agg({'order_number': ['mean']})

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.805603
# 2     17.091743
# 3     17.933180
# 4     17.901477
# 5     15.211405
# 6     15.382228
# 7     17.700476
# 8     16.485269
# 9     15.967282
# 10    20.091818
# 11    16.484907
# 12    15.620661
# 13    16.490636
# 14    17.502079
# 15    15.695987
# 16    18.017144
# 17    16.155822
# 18    19.606536
# 19    17.634215
# 20    17.145616
# 21    22.014421
# Name: order_number, dtype: float64

# %%
#Aggregating based on multiple arguments

df.groupby('department_id').agg({'order_number':['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.805603   1  99
# 2                17.091743   1  98
# 3                17.933180   1  99
# 4                17.901477   1  99
# 5                15.211405   1  99
# 6                15.382228   1  99
# 7                17.700476   1  99
# 8                16.485269   1  91
# 9                15.967282   1  99
# 10               20.091818   1  99
# 11               16.484907   1  99
# 12               15.620661   1  99
# 13               16.490636   1  99
# 14               17.502079   1  99
# 15               15.695987   1  99
# 16               18.017144   1  99
# 17               16.155822   1  99
# 18               19.606536   1  99
# 19               17.634215   1  99
# 20               17.145616   1  99
# 21               22.014421   1  97

# %% [markdown]
# ## Generating a customer loyalty flag

# %%
# Setting group by of the user_id column and applying the transform function over order_number

ords_prods_merge['max_order']= ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

ords_prods_merge.head()
# Out:
# /var/folders/c3/gxzbvq9x1032lnrpvbyhdtrw0000gn/T/ipykernel_28825/1639400810.py:3: FutureWarning: The provided callable <function max at 0x12a033740> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order']= ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
#
#    order_time_hour_of_day  days_since_prior_order  product_id  \
# 0                       8               11.114836         196
# 1                       8               11.114836       14084
# ...

# %%
#Using Loc()funciton for condition if statements

ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag']= 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']<= 40) & (ords_prods_merge['max_order']>10), 'loyalty_flag']= 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10, 'loyalty_flag']= 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna= False)
# Out:
# loyalty_flag
# Regular customer    15888429
# Loyal customer      10292407
# New customer         6248249
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
#
#    order_time_hour_of_day  days_since_prior_order  product_id  \
# 0                       8               11.114836         196
# 1                       8               11.114836       14084
# 2                       8               11.114836       12427
# 3                       8               11.114836       26088
# 4                       8               11.114836       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# 1                  2          0  Organic Unsweetened Vanilla Almond Milk
# ...

# %% [markdown]
# ## Exporting dataframe as a pickle file.

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.8 ords_prods_merged part A.pkl'))
